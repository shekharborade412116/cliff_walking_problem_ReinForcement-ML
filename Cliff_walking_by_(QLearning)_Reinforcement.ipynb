# %%
import gymnasium as gym
import numpy as np
import random

# %%
gamma=0.99
epsilon=0.1
alpha=0.5
episode=500

# %%
Q = np.zeros((48,4))

# %%
# epsilon-policy

def epsilon_greedy(state):
    if random.random()<epsilon:
        return env.action_space.sample()# explore
    else:
        return np.argmax(Q[state])

# %%
# Q-learning

for episode in range(episode):
    render=(episode % 50==0)

    if render:
        env=gym.make("CliffWalking-v1",render_mode="human")
    else:
        env=gym.make("CliffWalking-v1")

    done=False
    state,_=env.reset()

    episode_len=0
    tot_reward=0

    while not done:
        action =epsilon_greedy(state)

        next_state,reward,terminated,truncated,_=env.step(action)
        done=terminated or truncated

        # Q-learning update

        Q[state,action]+=alpha*(reward+gamma*np.max(Q[next_state])-Q[state,action])

        state=next_state

        episode_len +=1
        tot_reward += reward

    print(f"episode={episode+1}/500 & total reward={tot_reward} & episode len ={episode_len}")
    env.close()
# Out:
# episode=1/500 & total reward=-73 & episode len =73
# episode=2/500 & total reward=-399 & episode len =102
# episode=3/500 & total reward=-1871 & episode len =584
# episode=4/500 & total reward=-197 & episode len =98
# episode=5/500 & total reward=-68 & episode len =68
# episode=6/500 & total reward=-146 & episode len =47
# episode=7/500 & total reward=-293 & episode len =95
# episode=8/500 & total reward=-67 & episode len =67
# episode=9/500 & total reward=-40 & episode len =40
# episode=10/500 & total reward=-177 & episode len =78
# episode=11/500 & total reward=-61 & episode len =61
# episode=12/500 & total reward=-28 & episode len =28
# episode=13/500 & total reward=-46 & episode len =46
# episode=14/500 & total reward=-183 & episode len =84
# episode=15/500 & total reward=-156 & episode len =57
# episode=16/500 & total reward=-182 & episode len =83
# episode=17/500 & total reward=-30 & episode len =30
# episode=18/500 & total reward=-30 & episode len =30
# episode=19/500 & total reward=-150 & episode len =51
# episode=20/500 & total reward=-33 & episode len =33
# episode=21/500 & total reward=-31 & episode len =31
# episode=22/500 & total reward=-26 & episode len =26
# episode=23/500 & total reward=-263 & episode len =65
# episode=24/500 & total reward=-37 & episode len =37
# episode=25/500 & total reward=-22 & episode len =22
# episode=26/500 & total reward=-31 & episode len =31
# episode=27/500 & total reward=-15 & episode len =15
# episode=28/500 & total reward=-168 & episode len =69
# episode=29/500 & total reward=-147 & episode len =48
# episode=30/500 & total reward=-43 & episode len =43
# episode=31/500 & total reward=-17 & episode len =17
# episode=32/500 & total reward=-32 & episode len =32
# episode=33/500 & total reward=-23 & episode len =23
# episode=34/500 & total reward=-25 & episode len =25
# episode=35/500 & total reward=-31 & episode len =31
# episode=36/500 & total reward=-21 & episode len =21
# episode=37/500 & total reward=-17 & episode len =17
# episode=38/500 & total reward=-15 & episode len =15
# episode=39/500 & total reward=-28 & episode len =28
# episode=40/500 & total reward=-33 & episode len =33
# episode=41/500 & total reward=-26 & episode len =26
# episode=42/500 & total reward=-27 & episode len =27
# episode=43/500 & total reward=-19 & episode len =19
# episode=44/500 & total reward=-143 & episode len =44
# episode=45/500 & total reward=-16 & episode len =16
# episode=46/500 & total reward=-18 & episode len =18
# episode=47/500 & total reward=-13 & episode len =13
# episode=48/500 & total reward=-17 & episode len =17
# episode=49/500 & total reward=-26 & episode len =26
# episode=50/500 & total reward=-15 & episode len =15
# episode=51/500 & total reward=-243 & episode len =45
# episode=52/500 & total reward=-14 & episode len =14
# episode=53/500 & total reward=-22 & episode len =22
# episode=54/500 & total reward=-15 & episode len =15
# episode=55/500 & total reward=-21 & episode len =21
# episode=56/500 & total reward=-18 & episode len =18
# episode=57/500 & total reward=-126 & episode len =27
# episode=58/500 & total reward=-15 & episode len =15
# episode=59/500 & total reward=-13 & episode len =13
# episode=60/500 & total reward=-236 & episode len =38
# episode=61/500 & total reward=-125 & episode len =26
# episode=62/500 & total reward=-124 & episode len =25
# episode=63/500 & total reward=-15 & episode len =15
# episode=64/500 & total reward=-13 & episode len =13
# episode=65/500 & total reward=-13 & episode len =13
# episode=66/500 & total reward=-13 & episode len =13
# episode=67/500 & total reward=-13 & episode len =13
# episode=68/500 & total reward=-227 & episode len =29
# episode=69/500 & total reward=-15 & episode len =15
# episode=70/500 & total reward=-118 & episode len =19
# episode=71/500 & total reward=-19 & episode len =19
# episode=72/500 & total reward=-13 & episode len =13
# episode=73/500 & total reward=-13 & episode len =13
# episode=74/500 & total reward=-13 & episode len =13
# episode=75/500 & total reward=-126 & episode len =27
# episode=76/500 & total reward=-13 & episode len =13
# episode=77/500 & total reward=-120 & episode len =21
# episode=78/500 & total reward=-123 & episode len =24
# episode=79/500 & total reward=-15 & episode len =15
# episode=80/500 & total reward=-130 & episode len =31
# episode=81/500 & total reward=-24 & episode len =24
# episode=82/500 & total reward=-116 & episode len =17
# episode=83/500 & total reward=-13 & episode len =13
# episode=84/500 & total reward=-16 & episode len =16
# episode=85/500 & total reward=-136 & episode len =37
# episode=86/500 & total reward=-126 & episode len =27
# episode=87/500 & total reward=-13 & episode len =13
# episode=88/500 & total reward=-13 & episode len =13
# episode=89/500 & total reward=-319 & episode len =22
# episode=90/500 & total reward=-15 & episode len =15
# episode=91/500 & total reward=-13 & episode len =13
# episode=92/500 & total reward=-13 & episode len =13
# episode=93/500 & total reward=-124 & episode len =25
# episode=94/500 & total reward=-17 & episode len =17
# episode=95/500 & total reward=-335 & episode len =38
# episode=96/500 & total reward=-15 & episode len =15
# episode=97/500 & total reward=-13 & episode len =13
# episode=98/500 & total reward=-13 & episode len =13
# episode=99/500 & total reward=-13 & episode len =13
# episode=100/500 & total reward=-14 & episode len =14
# episode=101/500 & total reward=-116 & episode len =17
# episode=102/500 & total reward=-13 & episode len =13
# episode=103/500 & total reward=-15 & episode len =15
# episode=104/500 & total reward=-122 & episode len =23
# episode=105/500 & total reward=-13 & episode len =13
# episode=106/500 & total reward=-15 & episode len =15
# episode=107/500 & total reward=-118 & episode len =19
# episode=108/500 & total reward=-120 & episode len =21
# episode=109/500 & total reward=-13 & episode len =13
# episode=110/500 & total reward=-18 & episode len =18
# episode=111/500 & total reward=-13 & episode len =13
# episode=112/500 & total reward=-119 & episode len =20
# episode=113/500 & total reward=-20 & episode len =20
# episode=114/500 & total reward=-19 & episode len =19
# episode=115/500 & total reward=-15 & episode len =15
# episode=116/500 & total reward=-13 & episode len =13
# episode=117/500 & total reward=-13 & episode len =13
# episode=118/500 & total reward=-15 & episode len =15
# episode=119/500 & total reward=-14 & episode len =14
# episode=120/500 & total reward=-26 & episode len =26
# episode=121/500 & total reward=-120 & episode len =21
# episode=122/500 & total reward=-122 & episode len =23
# episode=123/500 & total reward=-13 & episode len =13
# episode=124/500 & total reward=-123 & episode len =24
# episode=125/500 & total reward=-13 & episode len =13
# episode=126/500 & total reward=-13 & episode len =13
# episode=127/500 & total reward=-117 & episode len =18
# episode=128/500 & total reward=-13 & episode len =13
# episode=129/500 & total reward=-122 & episode len =23
# episode=130/500 & total reward=-122 & episode len =23
# episode=131/500 & total reward=-226 & episode len =28
# episode=132/500 & total reward=-21 & episode len =21
# episode=133/500 & total reward=-14 & episode len =14
# episode=134/500 & total reward=-15 & episode len =15
# episode=135/500 & total reward=-15 & episode len =15
# episode=136/500 & total reward=-13 & episode len =13
# episode=137/500 & total reward=-121 & episode len =22
# episode=138/500 & total reward=-14 & episode len =14
# episode=139/500 & total reward=-123 & episode len =24
# episode=140/500 & total reward=-15 & episode len =15
# episode=141/500 & total reward=-333 & episode len =36
# episode=142/500 & total reward=-14 & episode len =14
# episode=143/500 & total reward=-15 & episode len =15
# episode=144/500 & total reward=-15 & episode len =15
# episode=145/500 & total reward=-118 & episode len =19
# episode=146/500 & total reward=-13 & episode len =13
# episode=147/500 & total reward=-232 & episode len =34
# episode=148/500 & total reward=-13 & episode len =13
# episode=149/500 & total reward=-15 & episode len =15
# episode=150/500 & total reward=-19 & episode len =19
# episode=151/500 & total reward=-122 & episode len =23
# episode=152/500 & total reward=-17 & episode len =17
# episode=153/500 & total reward=-15 & episode len =15
# episode=154/500 & total reward=-18 & episode len =18
# episode=155/500 & total reward=-225 & episode len =27
# episode=156/500 & total reward=-16 & episode len =16
# episode=157/500 & total reward=-14 & episode len =14
# episode=158/500 & total reward=-15 & episode len =15
# episode=159/500 & total reward=-15 & episode len =15
# episode=160/500 & total reward=-223 & episode len =25
# episode=161/500 & total reward=-121 & episode len =22
# episode=162/500 & total reward=-121 & episode len =22
# episode=163/500 & total reward=-13 & episode len =13
# episode=164/500 & total reward=-13 & episode len =13
# episode=165/500 & total reward=-15 & episode len =15
# episode=166/500 & total reward=-13 & episode len =13
# episode=167/500 & total reward=-13 & episode len =13
# episode=168/500 & total reward=-119 & episode len =20
# episode=169/500 & total reward=-126 & episode len =27
# episode=170/500 & total reward=-17 & episode len =17
# episode=171/500 & total reward=-13 & episode len =13
# episode=172/500 & total reward=-230 & episode len =32
# episode=173/500 & total reward=-13 & episode len =13
# episode=174/500 & total reward=-15 & episode len =15
# episode=175/500 & total reward=-13 & episode len =13
# episode=176/500 & total reward=-13 & episode len =13
# episode=177/500 & total reward=-13 & episode len =13
# episode=178/500 & total reward=-119 & episode len =20
# episode=179/500 & total reward=-13 & episode len =13
# episode=180/500 & total reward=-14 & episode len =14
# episode=181/500 & total reward=-13 & episode len =13
# episode=182/500 & total reward=-17 & episode len =17
# episode=183/500 & total reward=-19 & episode len =19
# episode=184/500 & total reward=-31 & episode len =31
# episode=185/500 & total reward=-13 & episode len =13
# episode=186/500 & total reward=-13 & episode len =13
# episode=187/500 & total reward=-17 & episode len =17
# episode=188/500 & total reward=-13 & episode len =13
# episode=189/500 & total reward=-15 & episode len =15
# episode=190/500 & total reward=-16 & episode len =16
# episode=191/500 & total reward=-16 & episode len =16
# episode=192/500 & total reward=-13 & episode len =13
# episode=193/500 & total reward=-13 & episode len =13
# episode=194/500 & total reward=-13 & episode len =13
# episode=195/500 & total reward=-15 & episode len =15
# episode=196/500 & total reward=-15 & episode len =15
# episode=197/500 & total reward=-15 & episode len =15
# episode=198/500 & total reward=-13 & episode len =13
# episode=199/500 & total reward=-21 & episode len =21
# episode=200/500 & total reward=-13 & episode len =13
# episode=201/500 & total reward=-119 & episode len =20
# episode=202/500 & total reward=-15 & episode len =15
# episode=203/500 & total reward=-13 & episode len =13
# episode=204/500 & total reward=-13 & episode len =13
# episode=205/500 & total reward=-16 & episode len =16
# episode=206/500 & total reward=-19 & episode len =19
# episode=207/500 & total reward=-116 & episode len =17
# episode=208/500 & total reward=-15 & episode len =15
# episode=209/500 & total reward=-118 & episode len =19
# episode=210/500 & total reward=-13 & episode len =13
# episode=211/500 & total reward=-13 & episode len =13
# episode=212/500 & total reward=-14 & episode len =14
# episode=213/500 & total reward=-14 & episode len =14
# episode=214/500 & total reward=-15 & episode len =15
# episode=215/500 & total reward=-17 & episode len =17
# episode=216/500 & total reward=-115 & episode len =16
# episode=217/500 & total reward=-13 & episode len =13
# episode=218/500 & total reward=-122 & episode len =23
# episode=219/500 & total reward=-13 & episode len =13
# episode=220/500 & total reward=-14 & episode len =14
# episode=221/500 & total reward=-15 & episode len =15
# episode=222/500 & total reward=-15 & episode len =15
# episode=223/500 & total reward=-14 & episode len =14
# episode=224/500 & total reward=-13 & episode len =13
# episode=225/500 & total reward=-130 & episode len =31
# episode=226/500 & total reward=-117 & episode len =18
# episode=227/500 & total reward=-13 & episode len =13
# episode=228/500 & total reward=-13 & episode len =13
# episode=229/500 & total reward=-125 & episode len =26
# episode=230/500 & total reward=-17 & episode len =17
# episode=231/500 & total reward=-25 & episode len =25
# episode=232/500 & total reward=-13 & episode len =13
# episode=233/500 & total reward=-13 & episode len =13
# episode=234/500 & total reward=-15 & episode len =15
# episode=235/500 & total reward=-15 & episode len =15
# episode=236/500 & total reward=-18 & episode len =18
# episode=237/500 & total reward=-122 & episode len =23
# episode=238/500 & total reward=-334 & episode len =37
# episode=239/500 & total reward=-22 & episode len =22
# episode=240/500 & total reward=-13 & episode len =13
# episode=241/500 & total reward=-13 & episode len =13
# episode=242/500 & total reward=-13 & episode len =13
# episode=243/500 & total reward=-13 & episode len =13
# episode=244/500 & total reward=-122 & episode len =23
# episode=245/500 & total reward=-15 & episode len =15
# episode=246/500 & total reward=-13 & episode len =13
# episode=247/500 & total reward=-13 & episode len =13
# episode=248/500 & total reward=-17 & episode len =17
# episode=249/500 & total reward=-113 & episode len =14
# episode=250/500 & total reward=-15 & episode len =15
# episode=251/500 & total reward=-119 & episode len =20
# episode=252/500 & total reward=-13 & episode len =13
# episode=253/500 & total reward=-13 & episode len =13
# episode=254/500 & total reward=-227 & episode len =29
# episode=255/500 & total reward=-115 & episode len =16
# episode=256/500 & total reward=-15 & episode len =15
# episode=257/500 & total reward=-127 & episode len =28
# episode=258/500 & total reward=-13 & episode len =13
# episode=259/500 & total reward=-19 & episode len =19
# episode=260/500 & total reward=-13 & episode len =13
# episode=261/500 & total reward=-13 & episode len =13
# episode=262/500 & total reward=-13 & episode len =13
# episode=263/500 & total reward=-17 & episode len =17
# episode=264/500 & total reward=-13 & episode len =13
# episode=265/500 & total reward=-119 & episode len =20
# episode=266/500 & total reward=-118 & episode len =19
# episode=267/500 & total reward=-14 & episode len =14
# episode=268/500 & total reward=-13 & episode len =13
# episode=269/500 & total reward=-13 & episode len =13
# episode=270/500 & total reward=-13 & episode len =13
# episode=271/500 & total reward=-15 & episode len =15
# episode=272/500 & total reward=-19 & episode len =19
# episode=273/500 & total reward=-13 & episode len =13
# episode=274/500 & total reward=-14 & episode len =14
# episode=275/500 & total reward=-13 & episode len =13
# episode=276/500 & total reward=-121 & episode len =22
# episode=277/500 & total reward=-17 & episode len =17
# episode=278/500 & total reward=-125 & episode len =26
# episode=279/500 & total reward=-14 & episode len =14
# episode=280/500 & total reward=-15 & episode len =15
# episode=281/500 & total reward=-13 & episode len =13
# episode=282/500 & total reward=-13 & episode len =13
# episode=283/500 & total reward=-15 & episode len =15
# episode=284/500 & total reward=-17 & episode len =17
# episode=285/500 & total reward=-121 & episode len =22
# episode=286/500 & total reward=-113 & episode len =14
# episode=287/500 & total reward=-13 & episode len =13
# episode=288/500 & total reward=-19 & episode len =19
# episode=289/500 & total reward=-13 & episode len =13
# episode=290/500 & total reward=-13 & episode len =13
# episode=291/500 & total reward=-13 & episode len =13
# episode=292/500 & total reward=-15 & episode len =15
# episode=293/500 & total reward=-14 & episode len =14
# episode=294/500 & total reward=-13 & episode len =13
# episode=295/500 & total reward=-15 & episode len =15
# episode=296/500 & total reward=-13 & episode len =13
# episode=297/500 & total reward=-116 & episode len =17
# episode=298/500 & total reward=-13 & episode len =13
# episode=299/500 & total reward=-19 & episode len =19
# episode=300/500 & total reward=-15 & episode len =15
# episode=301/500 & total reward=-15 & episode len =15
# episode=302/500 & total reward=-116 & episode len =17
# episode=303/500 & total reward=-14 & episode len =14
# episode=304/500 & total reward=-13 & episode len =13
# episode=305/500 & total reward=-16 & episode len =16
# episode=306/500 & total reward=-13 & episode len =13
# episode=307/500 & total reward=-22 & episode len =22
# episode=308/500 & total reward=-16 & episode len =16
# episode=309/500 & total reward=-13 & episode len =13
# episode=310/500 & total reward=-118 & episode len =19
# episode=311/500 & total reward=-15 & episode len =15
# episode=312/500 & total reward=-13 & episode len =13
# episode=313/500 & total reward=-13 & episode len =13
# episode=314/500 & total reward=-13 & episode len =13
# episode=315/500 & total reward=-13 & episode len =13
# episode=316/500 & total reward=-115 & episode len =16
# episode=317/500 & total reward=-15 & episode len =15
# episode=318/500 & total reward=-125 & episode len =26
# episode=319/500 & total reward=-117 & episode len =18
# episode=320/500 & total reward=-13 & episode len =13
# episode=321/500 & total reward=-17 & episode len =17
# episode=322/500 & total reward=-17 & episode len =17
# episode=323/500 & total reward=-13 & episode len =13
# episode=324/500 & total reward=-17 & episode len =17
# episode=325/500 & total reward=-15 & episode len =15
# episode=326/500 & total reward=-126 & episode len =27
# episode=327/500 & total reward=-13 & episode len =13
# episode=328/500 & total reward=-127 & episode len =28
# episode=329/500 & total reward=-15 & episode len =15
# episode=330/500 & total reward=-15 & episode len =15
# episode=331/500 & total reward=-13 & episode len =13
# episode=332/500 & total reward=-18 & episode len =18
# episode=333/500 & total reward=-13 & episode len =13
# episode=334/500 & total reward=-13 & episode len =13
# episode=335/500 & total reward=-13 & episode len =13
# episode=336/500 & total reward=-113 & episode len =14
# episode=337/500 & total reward=-17 & episode len =17
# episode=338/500 & total reward=-16 & episode len =16
# episode=339/500 & total reward=-13 & episode len =13
# episode=340/500 & total reward=-123 & episode len =24
# episode=341/500 & total reward=-13 & episode len =13
# episode=342/500 & total reward=-17 & episode len =17
# episode=343/500 & total reward=-118 & episode len =19
# episode=344/500 & total reward=-331 & episode len =34
# episode=345/500 & total reward=-121 & episode len =22
# episode=346/500 & total reward=-13 & episode len =13
# episode=347/500 & total reward=-15 & episode len =15
# episode=348/500 & total reward=-18 & episode len =18
# episode=349/500 & total reward=-13 & episode len =13
# episode=350/500 & total reward=-130 & episode len =31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       9     env=gym.make("CliffWalking-v1")
#      11 done=False
# ---> 12 state,_=env.reset()
#      14 episode_len=0
#      15 tot_reward=0
#
# File ~\AppData\Roaming\Python\Python313\site-packages\gymnasium\wrappers\common.py:399, in OrderEnforcing.reset(self, seed, options)
#     397 """Resets the environment with `kwargs`."""
#     398 self._has_reset = True
# --> 399 return super().reset(seed=seed, options=options)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\gymnasium\core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
#     330     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     331 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     332     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 333     return self.env.reset(seed=seed, options=options)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\gymnasium\wrappers\common.py:292, in PassiveEnvChecker.reset(self, seed, options)
#     290 if self.checked_reset is False:
#     291     self.checked_reset = True
# --> 292     return env_reset_passive_checker(self.env, seed=seed, options=options)
#     293 else:
#     294     return self.env.reset(seed=seed, options=options)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\gymnasium\utils\passive_env_checker.py:184, in env_reset_passive_checker(env, **kwargs)
#     179     logger.deprecation(
#     180         "Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information."
#     181     )
#     183 # Checks the result of env.reset with kwargs
# --> 184 result = env.reset(**kwargs)
#     186 if not isinstance(result, tuple):
#     187     logger.warn(
#     188         f"The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `{type(result)}`"
#     189     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\gymnasium\envs\toy_text\cliffwalking.py:211, in CliffWalkingEnv.reset(self, seed, options)
#     208 self.lastaction = None
#     210 if self.render_mode == "human":
# --> 211     self.render()
#     212 return int(self.s), {"prob": 1}
#
# File ~\AppData\Roaming\Python\Python313\site-packages\gymnasium\envs\toy_text\cliffwalking.py:227, in CliffWalkingEnv.render(self)
#     225     return self._render_text()
#     226 else:
# --> 227     return self._render_gui(self.render_mode)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\gymnasium\envs\toy_text\cliffwalking.py:240, in CliffWalkingEnv._render_gui(self, mode)
#     237 pygame.init()
#     239 if mode == "human":
# --> 240     pygame.display.init()
#     241     pygame.display.set_caption("CliffWalking")
#     242     self.window_surface = pygame.display.set_mode(self.window_size)
#
# KeyboardInterrupt:
