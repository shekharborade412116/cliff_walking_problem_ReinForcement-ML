# %%
# !pip install gymnasium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gymnasium
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    -------------------------------- ------- 786.4/953.9 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 953.9/953.9 kB 3.1 MB/s  0:00:00
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Installing collected packages: farama-notifications, gymnasium
#
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    ---------------------------------------- 2/2 [gymnasium]
#
# Successfully installed farama-notifications-0.0.6 gymnasium-1.3.0

# %%
# !pip install gymnasium["toy-text"]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium[toy-text] in c:\users\hp\appdata\roaming\python\python313\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium[toy-text]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium[toy-text]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\programdata\anaconda3\lib\site-packages (from gymnasium[toy-text]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from gymnasium[toy-text]) (0.0.6)
# Collecting pygame-ce>=2.1.3 (from gymnasium[toy-text])
#   Downloading pygame_ce-2.5.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Downloading pygame_ce-2.5.7-cp313-cp313-win_amd64.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.4 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/10.4 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/10.4 MB 4.0 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/10.4 MB 3.4 MB/s eta 0:00:03
#    --------------------- ------------------ 5.5/10.4 MB 4.6 MB/s eta 0:00:02
#    --------------------- ------------------ 5.5/10.4 MB 4.6 MB/s eta 0:00:02
#    -------------------------- ------------- 6.8/10.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.3/10.4 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.4 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 4.8 MB/s  0:00:02
# Installing collected packages: pygame-ce
# Successfully installed pygame-ce-2.5.7

# %%
import gymnasium as gym
import numpy as np
import random

# %%
# sample env

env=gym.make("CliffWalking-v1")

# %%
env
# Out:
# <OrderEnforcing<PassiveEnvChecker<CliffWalkingEnv<CliffWalking-v1>>>>

# %%
print(env.observation_space.n)# states
print(env.action_space.n) # actions

starting_state,_=env.reset()
print(starting_state)
# Out:
# 48
# 4
# 36

# %%
gamma=0.99
alpha=0.5
episodes=500
epsilon=0.1

# %%
# Q-table=>store Q-value

Q=np.zeros((48,4))

# %%
# policy- epsilon-greedy: state ke basis pe action batati hai

def epsilon_greedy(state):
  if random.random()<epsilon:
    return env.action_space.sample() # random action =>EXPLORE
  else:
    return np.argmax (Q[state])# exploit

# %%
for episode in range(episodes):
  render=(episode % 50 == 0 )

  if render:
    env=gym.make("CliffWalking-v1",render_mode="human")
    print(f"rendering env for episode ={episode+1}/500")

  else:
    env=gym.make("CliffWalking-v1")
  

  done=False # when the episode has ended
  state,_=env.reset()
  action=epsilon_greedy(state)

  total_reward=0
  episode_len=0

  while not done:
    next_state,reward,terminated,truncated,_ =env.step(action)
    done=terminated or truncated
    next_action=epsilon_greedy(next_state)

    # SARSA Update
    Q[state,action] +=alpha*(reward + gamma*(Q[next_state,next_action]-Q[state,action]))
    
    state=next_state
    action=next_action

    total_reward += reward
    episode_len += 1

  print(f"episode={episode+1}/500:total reward={total_reward} & ep length={episode_len}")
  env.close()
# Out:
# rendering env for episode =1/500
# episode=1/500:total reward=-19 & ep length=19
# episode=2/500:total reward=-17 & ep length=17
# episode=3/500:total reward=-17 & ep length=17
# episode=4/500:total reward=-19 & ep length=19
# episode=5/500:total reward=-29 & ep length=29
# episode=6/500:total reward=-17 & ep length=17
# episode=7/500:total reward=-20 & ep length=20
# episode=8/500:total reward=-17 & ep length=17
# episode=9/500:total reward=-22 & ep length=22
# episode=10/500:total reward=-19 & ep length=19
# episode=11/500:total reward=-39 & ep length=39
# episode=12/500:total reward=-21 & ep length=21
# episode=13/500:total reward=-18 & ep length=18
# episode=14/500:total reward=-18 & ep length=18
# episode=15/500:total reward=-22 & ep length=22
# episode=16/500:total reward=-17 & ep length=17
# episode=17/500:total reward=-27 & ep length=27
# episode=18/500:total reward=-32 & ep length=32
# episode=19/500:total reward=-20 & ep length=20
# episode=20/500:total reward=-19 & ep length=19
# episode=21/500:total reward=-18 & ep length=18
# episode=22/500:total reward=-27 & ep length=27
# episode=23/500:total reward=-17 & ep length=17
# episode=24/500:total reward=-117 & ep length=18
# episode=25/500:total reward=-17 & ep length=17
# episode=26/500:total reward=-17 & ep length=17
# episode=27/500:total reward=-17 & ep length=17
# episode=28/500:total reward=-18 & ep length=18
# episode=29/500:total reward=-19 & ep length=19
# episode=30/500:total reward=-17 & ep length=17
# episode=31/500:total reward=-23 & ep length=23
# episode=32/500:total reward=-20 & ep length=20
# episode=33/500:total reward=-25 & ep length=25
# episode=34/500:total reward=-24 & ep length=24
# episode=35/500:total reward=-20 & ep length=20
# episode=36/500:total reward=-17 & ep length=17
# episode=37/500:total reward=-21 & ep length=21
# episode=38/500:total reward=-134 & ep length=35
# episode=39/500:total reward=-19 & ep length=19
# episode=40/500:total reward=-17 & ep length=17
# episode=41/500:total reward=-19 & ep length=19
# episode=42/500:total reward=-129 & ep length=30
# episode=43/500:total reward=-19 & ep length=19
# episode=44/500:total reward=-19 & ep length=19
# episode=45/500:total reward=-23 & ep length=23
# episode=46/500:total reward=-19 & ep length=19
# episode=47/500:total reward=-23 & ep length=23
# episode=48/500:total reward=-19 & ep length=19
# episode=49/500:total reward=-22 & ep length=22
# episode=50/500:total reward=-22 & ep length=22
# rendering env for episode =51/500
# episode=51/500:total reward=-21 & ep length=21
# episode=52/500:total reward=-21 & ep length=21
# episode=53/500:total reward=-19 & ep length=19
# episode=54/500:total reward=-17 & ep length=17
# episode=55/500:total reward=-23 & ep length=23
# episode=56/500:total reward=-17 & ep length=17
# episode=57/500:total reward=-19 & ep length=19
# episode=58/500:total reward=-17 & ep length=17
# episode=59/500:total reward=-17 & ep length=17
# episode=60/500:total reward=-17 & ep length=17
# episode=61/500:total reward=-17 & ep length=17
# episode=62/500:total reward=-18 & ep length=18
# episode=63/500:total reward=-20 & ep length=20
# episode=64/500:total reward=-17 & ep length=17
# episode=65/500:total reward=-17 & ep length=17
# episode=66/500:total reward=-25 & ep length=25
# episode=67/500:total reward=-19 & ep length=19
# episode=68/500:total reward=-19 & ep length=19
# episode=69/500:total reward=-23 & ep length=23
# episode=70/500:total reward=-21 & ep length=21
# episode=71/500:total reward=-18 & ep length=18
# episode=72/500:total reward=-18 & ep length=18
# episode=73/500:total reward=-21 & ep length=21
# episode=74/500:total reward=-27 & ep length=27
# episode=75/500:total reward=-17 & ep length=17
# episode=76/500:total reward=-17 & ep length=17
# episode=77/500:total reward=-21 & ep length=21
# episode=78/500:total reward=-21 & ep length=21
# episode=79/500:total reward=-117 & ep length=18
# episode=80/500:total reward=-17 & ep length=17
# episode=81/500:total reward=-29 & ep length=29
# episode=82/500:total reward=-19 & ep length=19
# episode=83/500:total reward=-24 & ep length=24
# episode=84/500:total reward=-19 & ep length=19
# episode=85/500:total reward=-24 & ep length=24
# episode=86/500:total reward=-21 & ep length=21
# episode=87/500:total reward=-17 & ep length=17
# episode=88/500:total reward=-17 & ep length=17
# episode=89/500:total reward=-19 & ep length=19
# episode=90/500:total reward=-271 & ep length=271
# episode=91/500:total reward=-40 & ep length=40
# episode=92/500:total reward=-61 & ep length=61
# episode=93/500:total reward=-33 & ep length=33
# episode=94/500:total reward=-35 & ep length=35
# episode=95/500:total reward=-35 & ep length=35
# episode=96/500:total reward=-31 & ep length=31
# episode=97/500:total reward=-29 & ep length=29
# episode=98/500:total reward=-29 & ep length=29
# episode=99/500:total reward=-25 & ep length=25
# episode=100/500:total reward=-26 & ep length=26
# rendering env for episode =101/500
# episode=101/500:total reward=-23 & ep length=23
# episode=102/500:total reward=-28 & ep length=28
# episode=103/500:total reward=-31 & ep length=31
# episode=104/500:total reward=-21 & ep length=21
# episode=105/500:total reward=-241 & ep length=43
# episode=106/500:total reward=-23 & ep length=23
# episode=107/500:total reward=-20 & ep length=20
# episode=108/500:total reward=-24 & ep length=24
# episode=109/500:total reward=-19 & ep length=19
# episode=110/500:total reward=-21 & ep length=21
# episode=111/500:total reward=-21 & ep length=21
# episode=112/500:total reward=-20 & ep length=20
# episode=113/500:total reward=-17 & ep length=17
# episode=114/500:total reward=-18 & ep length=18
# episode=115/500:total reward=-17 & ep length=17
# episode=116/500:total reward=-17 & ep length=17
# episode=117/500:total reward=-22 & ep length=22
# episode=118/500:total reward=-28 & ep length=28
# episode=119/500:total reward=-17 & ep length=17
# episode=120/500:total reward=-18 & ep length=18
# episode=121/500:total reward=-22 & ep length=22
# episode=122/500:total reward=-24 & ep length=24
# episode=123/500:total reward=-18 & ep length=18
# episode=124/500:total reward=-72 & ep length=72
# episode=125/500:total reward=-60 & ep length=60
# episode=126/500:total reward=-17 & ep length=17
# episode=127/500:total reward=-25 & ep length=25
# episode=128/500:total reward=-20 & ep length=20
# episode=129/500:total reward=-22 & ep length=22
# episode=130/500:total reward=-19 & ep length=19
# episode=131/500:total reward=-24 & ep length=24
# episode=132/500:total reward=-21 & ep length=21
# episode=133/500:total reward=-24 & ep length=24
# episode=134/500:total reward=-21 & ep length=21
# episode=135/500:total reward=-19 & ep length=19
# episode=136/500:total reward=-21 & ep length=21
# episode=137/500:total reward=-31 & ep length=31
# episode=138/500:total reward=-18 & ep length=18
# episode=139/500:total reward=-25 & ep length=25
# episode=140/500:total reward=-17 & ep length=17
# episode=141/500:total reward=-17 & ep length=17
# episode=142/500:total reward=-20 & ep length=20
# episode=143/500:total reward=-18 & ep length=18
# episode=144/500:total reward=-121 & ep length=22
# episode=145/500:total reward=-23 & ep length=23
# episode=146/500:total reward=-20 & ep length=20
# episode=147/500:total reward=-21 & ep length=21
# episode=148/500:total reward=-86 & ep length=86
# episode=149/500:total reward=-51 & ep length=51
# episode=150/500:total reward=-43 & ep length=43
# rendering env for episode =151/500
# episode=151/500:total reward=-38 & ep length=38
# episode=152/500:total reward=-33 & ep length=33
# episode=153/500:total reward=-21 & ep length=21
# episode=154/500:total reward=-23 & ep length=23
# episode=155/500:total reward=-129 & ep length=30
# episode=156/500:total reward=-23 & ep length=23
# episode=157/500:total reward=-28 & ep length=28
# episode=158/500:total reward=-21 & ep length=21
# episode=159/500:total reward=-21 & ep length=21
# episode=160/500:total reward=-21 & ep length=21
# episode=161/500:total reward=-19 & ep length=19
# episode=162/500:total reward=-21 & ep length=21
# episode=163/500:total reward=-19 & ep length=19
# episode=164/500:total reward=-19 & ep length=19
# episode=165/500:total reward=-36 & ep length=36
# episode=166/500:total reward=-25 & ep length=25
# episode=167/500:total reward=-31 & ep length=31
# episode=168/500:total reward=-19 & ep length=19
# episode=169/500:total reward=-23 & ep length=23
# episode=170/500:total reward=-63 & ep length=63
# episode=171/500:total reward=-48 & ep length=48
# episode=172/500:total reward=-21 & ep length=21
# episode=173/500:total reward=-24 & ep length=24
# episode=174/500:total reward=-28 & ep length=28
# episode=175/500:total reward=-21 & ep length=21
# episode=176/500:total reward=-18 & ep length=18
# episode=177/500:total reward=-19 & ep length=19
# episode=178/500:total reward=-24 & ep length=24
# episode=179/500:total reward=-17 & ep length=17
# episode=180/500:total reward=-19 & ep length=19
# episode=181/500:total reward=-20 & ep length=20
# episode=182/500:total reward=-20 & ep length=20
# episode=183/500:total reward=-25 & ep length=25
# episode=184/500:total reward=-25 & ep length=25
# episode=185/500:total reward=-40 & ep length=40
# episode=186/500:total reward=-17 & ep length=17
# episode=187/500:total reward=-20 & ep length=20
# episode=188/500:total reward=-24 & ep length=24
# episode=189/500:total reward=-22 & ep length=22
# episode=190/500:total reward=-23 & ep length=23
# episode=191/500:total reward=-27 & ep length=27
# episode=192/500:total reward=-17 & ep length=17
# episode=193/500:total reward=-17 & ep length=17
# episode=194/500:total reward=-17 & ep length=17
# episode=195/500:total reward=-19 & ep length=19
# episode=196/500:total reward=-17 & ep length=17
# episode=197/500:total reward=-18 & ep length=18
# episode=198/500:total reward=-17 & ep length=17
# episode=199/500:total reward=-17 & ep length=17
# episode=200/500:total reward=-17 & ep length=17
# rendering env for episode =201/500
# episode=201/500:total reward=-18 & ep length=18
# episode=202/500:total reward=-17 & ep length=17
# episode=203/500:total reward=-23 & ep length=23
# episode=204/500:total reward=-22 & ep length=22
# episode=205/500:total reward=-19 & ep length=19
# episode=206/500:total reward=-24 & ep length=24
# episode=207/500:total reward=-20 & ep length=20
# episode=208/500:total reward=-19 & ep length=19
# episode=209/500:total reward=-25 & ep length=25
# episode=210/500:total reward=-33 & ep length=33
# episode=211/500:total reward=-20 & ep length=20
# episode=212/500:total reward=-19 & ep length=19
# episode=213/500:total reward=-58 & ep length=58
# episode=214/500:total reward=-30 & ep length=30
# episode=215/500:total reward=-68 & ep length=68
# episode=216/500:total reward=-35 & ep length=35
# episode=217/500:total reward=-20 & ep length=20
# episode=218/500:total reward=-27 & ep length=27
# episode=219/500:total reward=-23 & ep length=23
# episode=220/500:total reward=-19 & ep length=19
# episode=221/500:total reward=-17 & ep length=17
# episode=222/500:total reward=-21 & ep length=21
# episode=223/500:total reward=-21 & ep length=21
# episode=224/500:total reward=-21 & ep length=21
# episode=225/500:total reward=-22 & ep length=22
# episode=226/500:total reward=-21 & ep length=21
# episode=227/500:total reward=-20 & ep length=20
# episode=228/500:total reward=-20 & ep length=20
# episode=229/500:total reward=-24 & ep length=24
# episode=230/500:total reward=-19 & ep length=19
# episode=231/500:total reward=-21 & ep length=21
# episode=232/500:total reward=-129 & ep length=30
# episode=233/500:total reward=-18 & ep length=18
# episode=234/500:total reward=-19 & ep length=19
# episode=235/500:total reward=-17 & ep length=17
# episode=236/500:total reward=-19 & ep length=19
# episode=237/500:total reward=-29 & ep length=29
# episode=238/500:total reward=-22 & ep length=22
# episode=239/500:total reward=-19 & ep length=19
# episode=240/500:total reward=-26 & ep length=26
# episode=241/500:total reward=-27 & ep length=27
# episode=242/500:total reward=-17 & ep length=17
# episode=243/500:total reward=-19 & ep length=19
# episode=244/500:total reward=-20 & ep length=20
# episode=245/500:total reward=-17 & ep length=17
# episode=246/500:total reward=-17 & ep length=17
# episode=247/500:total reward=-17 & ep length=17
# episode=248/500:total reward=-19 & ep length=19
# episode=249/500:total reward=-19 & ep length=19
# episode=250/500:total reward=-17 & ep length=17
# rendering env for episode =251/500
# episode=251/500:total reward=-19 & ep length=19
# episode=252/500:total reward=-17 & ep length=17
# episode=253/500:total reward=-22 & ep length=22
# episode=254/500:total reward=-17 & ep length=17
# episode=255/500:total reward=-19 & ep length=19
# episode=256/500:total reward=-18 & ep length=18
# episode=257/500:total reward=-19 & ep length=19
# episode=258/500:total reward=-19 & ep length=19
# episode=259/500:total reward=-18 & ep length=18
# episode=260/500:total reward=-23 & ep length=23
# episode=261/500:total reward=-20 & ep length=20
# episode=262/500:total reward=-25 & ep length=25
# episode=263/500:total reward=-18 & ep length=18
# episode=264/500:total reward=-18 & ep length=18
# episode=265/500:total reward=-117 & ep length=18
# episode=266/500:total reward=-18 & ep length=18
# episode=267/500:total reward=-17 & ep length=17
# episode=268/500:total reward=-21 & ep length=21
# episode=269/500:total reward=-17 & ep length=17
# episode=270/500:total reward=-17 & ep length=17
# episode=271/500:total reward=-21 & ep length=21
# episode=272/500:total reward=-21 & ep length=21
# episode=273/500:total reward=-24 & ep length=24
# episode=274/500:total reward=-17 & ep length=17
# episode=275/500:total reward=-28 & ep length=28
# episode=276/500:total reward=-24 & ep length=24
# episode=277/500:total reward=-117 & ep length=18
# episode=278/500:total reward=-20 & ep length=20
# episode=279/500:total reward=-17 & ep length=17
# episode=280/500:total reward=-17 & ep length=17
# episode=281/500:total reward=-21 & ep length=21
# episode=282/500:total reward=-29 & ep length=29
# episode=283/500:total reward=-20 & ep length=20
# episode=284/500:total reward=-19 & ep length=19
# episode=285/500:total reward=-17 & ep length=17
# episode=286/500:total reward=-18 & ep length=18
# episode=287/500:total reward=-19 & ep length=19
# episode=288/500:total reward=-20 & ep length=20
# episode=289/500:total reward=-17 & ep length=17
# episode=290/500:total reward=-18 & ep length=18
# episode=291/500:total reward=-18 & ep length=18
# episode=292/500:total reward=-17 & ep length=17
# episode=293/500:total reward=-19 & ep length=19
# episode=294/500:total reward=-17 & ep length=17
# episode=295/500:total reward=-22 & ep length=22
# episode=296/500:total reward=-17 & ep length=17
# episode=297/500:total reward=-18 & ep length=18
# episode=298/500:total reward=-18 & ep length=18
# episode=299/500:total reward=-117 & ep length=18
# episode=300/500:total reward=-24 & ep length=24
# rendering env for episode =301/500
# episode=301/500:total reward=-27 & ep length=27
# episode=302/500:total reward=-17 & ep length=17
# episode=303/500:total reward=-24 & ep length=24
# episode=304/500:total reward=-24 & ep length=24
# episode=305/500:total reward=-21 & ep length=21
# episode=306/500:total reward=-21 & ep length=21
# episode=307/500:total reward=-17 & ep length=17
# episode=308/500:total reward=-21 & ep length=21
# episode=309/500:total reward=-17 & ep length=17
# episode=310/500:total reward=-21 & ep length=21
# episode=311/500:total reward=-18 & ep length=18
# episode=312/500:total reward=-17 & ep length=17
# episode=313/500:total reward=-17 & ep length=17
# episode=314/500:total reward=-19 & ep length=19
# episode=315/500:total reward=-18 & ep length=18
# episode=316/500:total reward=-20 & ep length=20
# episode=317/500:total reward=-19 & ep length=19
# episode=318/500:total reward=-21 & ep length=21
# episode=319/500:total reward=-19 & ep length=19
# episode=320/500:total reward=-17 & ep length=17
# episode=321/500:total reward=-21 & ep length=21
# episode=322/500:total reward=-17 & ep length=17
# episode=323/500:total reward=-19 & ep length=19
# episode=324/500:total reward=-20 & ep length=20
# episode=325/500:total reward=-19 & ep length=19
# episode=326/500:total reward=-18 & ep length=18
# episode=327/500:total reward=-22 & ep length=22
# episode=328/500:total reward=-40 & ep length=40
# episode=329/500:total reward=-19 & ep length=19
# episode=330/500:total reward=-22 & ep length=22
# episode=331/500:total reward=-20 & ep length=20
# episode=332/500:total reward=-19 & ep length=19
# episode=333/500:total reward=-17 & ep length=17
# episode=334/500:total reward=-18 & ep length=18
# episode=335/500:total reward=-19 & ep length=19
# episode=336/500:total reward=-24 & ep length=24
# episode=337/500:total reward=-25 & ep length=25
# episode=338/500:total reward=-120 & ep length=21
# episode=339/500:total reward=-19 & ep length=19
# episode=340/500:total reward=-20 & ep length=20
# episode=341/500:total reward=-19 & ep length=19
# episode=342/500:total reward=-17 & ep length=17
# episode=343/500:total reward=-17 & ep length=17
# episode=344/500:total reward=-23 & ep length=23
# episode=345/500:total reward=-19 & ep length=19
# episode=346/500:total reward=-17 & ep length=17
# episode=347/500:total reward=-19 & ep length=19
# episode=348/500:total reward=-17 & ep length=17
# episode=349/500:total reward=-17 & ep length=17
# episode=350/500:total reward=-26 & ep length=26
# rendering env for episode =351/500
# episode=351/500:total reward=-20 & ep length=20
# episode=352/500:total reward=-20 & ep length=20
# episode=353/500:total reward=-17 & ep length=17
# episode=354/500:total reward=-24 & ep length=24
# episode=355/500:total reward=-20 & ep length=20
# episode=356/500:total reward=-20 & ep length=20
# episode=357/500:total reward=-18 & ep length=18
# episode=358/500:total reward=-22 & ep length=22
# episode=359/500:total reward=-20 & ep length=20
# episode=360/500:total reward=-19 & ep length=19
# episode=361/500:total reward=-17 & ep length=17
# episode=362/500:total reward=-19 & ep length=19
# episode=363/500:total reward=-21 & ep length=21
# episode=364/500:total reward=-17 & ep length=17
# episode=365/500:total reward=-21 & ep length=21
# episode=366/500:total reward=-18 & ep length=18
# episode=367/500:total reward=-18 & ep length=18
# episode=368/500:total reward=-17 & ep length=17
# episode=369/500:total reward=-21 & ep length=21
# episode=370/500:total reward=-17 & ep length=17
# episode=371/500:total reward=-23 & ep length=23
# episode=372/500:total reward=-18 & ep length=18
# episode=373/500:total reward=-23 & ep length=23
# episode=374/500:total reward=-18 & ep length=18
# episode=375/500:total reward=-17 & ep length=17
# episode=376/500:total reward=-19 & ep length=19
# episode=377/500:total reward=-28 & ep length=28
# episode=378/500:total reward=-21 & ep length=21
# episode=379/500:total reward=-18 & ep length=18
# episode=380/500:total reward=-18 & ep length=18
# episode=381/500:total reward=-21 & ep length=21
# episode=382/500:total reward=-18 & ep length=18
# episode=383/500:total reward=-129 & ep length=30
# episode=384/500:total reward=-19 & ep length=19
# episode=385/500:total reward=-18 & ep length=18
# episode=386/500:total reward=-18 & ep length=18
# episode=387/500:total reward=-30 & ep length=30
# episode=388/500:total reward=-123 & ep length=24
# episode=389/500:total reward=-21 & ep length=21
# episode=390/500:total reward=-20 & ep length=20
# episode=391/500:total reward=-17 & ep length=17
# episode=392/500:total reward=-17 & ep length=17
# episode=393/500:total reward=-19 & ep length=19
# episode=394/500:total reward=-22 & ep length=22
# episode=395/500:total reward=-18 & ep length=18
# episode=396/500:total reward=-17 & ep length=17
# episode=397/500:total reward=-19 & ep length=19
# episode=398/500:total reward=-20 & ep length=20
# episode=399/500:total reward=-122 & ep length=23
# episode=400/500:total reward=-19 & ep length=19
# rendering env for episode =401/500
# episode=401/500:total reward=-20 & ep length=20
# episode=402/500:total reward=-218 & ep length=20
# episode=403/500:total reward=-27 & ep length=27
# episode=404/500:total reward=-21 & ep length=21
# episode=405/500:total reward=-21 & ep length=21
# episode=406/500:total reward=-17 & ep length=17
# episode=407/500:total reward=-17 & ep length=17
# episode=408/500:total reward=-17 & ep length=17
# episode=409/500:total reward=-20 & ep length=20
# episode=410/500:total reward=-19 & ep length=19
# episode=411/500:total reward=-19 & ep length=19
# episode=412/500:total reward=-34 & ep length=34
# episode=413/500:total reward=-21 & ep length=21
# episode=414/500:total reward=-28 & ep length=28
# episode=415/500:total reward=-19 & ep length=19
# episode=416/500:total reward=-21 & ep length=21
# episode=417/500:total reward=-17 & ep length=17
# episode=418/500:total reward=-17 & ep length=17
# episode=419/500:total reward=-22 & ep length=22
# episode=420/500:total reward=-21 & ep length=21
# episode=421/500:total reward=-121 & ep length=22
# episode=422/500:total reward=-25 & ep length=25
# episode=423/500:total reward=-23 & ep length=23
# episode=424/500:total reward=-19 & ep length=19
# episode=425/500:total reward=-17 & ep length=17
# episode=426/500:total reward=-19 & ep length=19
# episode=427/500:total reward=-22 & ep length=22
# episode=428/500:total reward=-22 & ep length=22
# episode=429/500:total reward=-21 & ep length=21
# episode=430/500:total reward=-17 & ep length=17
# episode=431/500:total reward=-20 & ep length=20
# episode=432/500:total reward=-19 & ep length=19
# episode=433/500:total reward=-17 & ep length=17
# episode=434/500:total reward=-22 & ep length=22
# episode=435/500:total reward=-19 & ep length=19
# episode=436/500:total reward=-24 & ep length=24
# episode=437/500:total reward=-19 & ep length=19
# episode=438/500:total reward=-17 & ep length=17
# episode=439/500:total reward=-17 & ep length=17
# episode=440/500:total reward=-20 & ep length=20
# episode=441/500:total reward=-22 & ep length=22
# episode=442/500:total reward=-20 & ep length=20
# episode=443/500:total reward=-30 & ep length=30
# episode=444/500:total reward=-17 & ep length=17
# episode=445/500:total reward=-18 & ep length=18
# episode=446/500:total reward=-21 & ep length=21
# episode=447/500:total reward=-19 & ep length=19
# episode=448/500:total reward=-19 & ep length=19
# episode=449/500:total reward=-17 & ep length=17
# episode=450/500:total reward=-219 & ep length=21
# rendering env for episode =451/500
# episode=451/500:total reward=-24 & ep length=24
# episode=452/500:total reward=-18 & ep length=18
# episode=453/500:total reward=-132 & ep length=33
# episode=454/500:total reward=-22 & ep length=22
# episode=455/500:total reward=-19 & ep length=19
# episode=456/500:total reward=-17 & ep length=17
# episode=457/500:total reward=-19 & ep length=19
# episode=458/500:total reward=-17 & ep length=17
# episode=459/500:total reward=-17 & ep length=17
# episode=460/500:total reward=-19 & ep length=19
# episode=461/500:total reward=-19 & ep length=19
# episode=462/500:total reward=-17 & ep length=17
# episode=463/500:total reward=-20 & ep length=20
# episode=464/500:total reward=-17 & ep length=17
# episode=465/500:total reward=-22 & ep length=22
# episode=466/500:total reward=-18 & ep length=18
# episode=467/500:total reward=-21 & ep length=21
# episode=468/500:total reward=-20 & ep length=20
# episode=469/500:total reward=-19 & ep length=19
# episode=470/500:total reward=-24 & ep length=24
# episode=471/500:total reward=-19 & ep length=19
# episode=472/500:total reward=-23 & ep length=23
# episode=473/500:total reward=-30 & ep length=30
# episode=474/500:total reward=-18 & ep length=18
# episode=475/500:total reward=-19 & ep length=19
# episode=476/500:total reward=-21 & ep length=21
# episode=477/500:total reward=-30 & ep length=30
# episode=478/500:total reward=-25 & ep length=25
# episode=479/500:total reward=-20 & ep length=20
# episode=480/500:total reward=-26 & ep length=26
# episode=481/500:total reward=-19 & ep length=19
# episode=482/500:total reward=-17 & ep length=17
# episode=483/500:total reward=-18 & ep length=18
# episode=484/500:total reward=-19 & ep length=19
# episode=485/500:total reward=-24 & ep length=24
# episode=486/500:total reward=-20 & ep length=20
# episode=487/500:total reward=-17 & ep length=17
# episode=488/500:total reward=-23 & ep length=23
# episode=489/500:total reward=-21 & ep length=21
# episode=490/500:total reward=-63 & ep length=63
# episode=491/500:total reward=-19 & ep length=19
# episode=492/500:total reward=-29 & ep length=29
# episode=493/500:total reward=-26 & ep length=26
# episode=494/500:total reward=-19 & ep length=19
# episode=495/500:total reward=-21 & ep length=21
# episode=496/500:total reward=-17 & ep length=17
# episode=497/500:total reward=-17 & ep length=17
# episode=498/500:total reward=-17 & ep length=17
# episode=499/500:total reward=-18 & ep length=18
# episode=500/500:total reward=-122 & ep length=23

# %%
# what did our agent learn?

env=gym.make("CliffWalking-v1",render_mode="human")
state,_ = env.reset()
done=False
total_reward=0
episode_len=0

while not done:
  action=np.argmax(Q[state])
  state,reward,terminated,truncated,_=env.step(action)
  done=terminated or truncated

  total_reward +=reward
  episode_len += 1

print(f"total reward= {total_reward} & episode len ={episode_len}")
env.close()
# Out:
# total reward= -17 & episode len =17
